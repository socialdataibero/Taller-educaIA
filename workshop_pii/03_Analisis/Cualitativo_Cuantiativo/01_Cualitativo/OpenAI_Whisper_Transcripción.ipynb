# %% [markdown]
# # **Whisper**

# %%
#@title 💻 Ejecutar esta celda para instalar las librerías.

# !pip install git+https://github.com/openai/whisper.git
# !pip install ffmpeg

# %%
#@title 🗂️  Montar la carpeta Drive

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#@title 🗂️ Colocar la ruta de nuestro directorio de trabajo

import os
os.chdir("/content/drive/MyDrive/09_DCenter/08_Comunidades_de_Aprendizaje/Programas/01_Whisper/")

# %%
#@title 🎼  Colocar el nombre de nuestro audio
audio = "Mito_y_oralidad_en_la_tradicion_mesoamericana_1_1.mp3"

# %%
#@title 🎛️ Nombrar el directorio de salida de nuestras transcripciones
output_dir = "transcript1"

# %%
#@title Ajustar algunos parámetros
model = "tiny"            # Otros modelos son: tiny, base, small, medium, large, large-v2, large-v3
device = "cpu"               # Otro valor es: cpu
fp16 = False                  # Otro valor es: True
verbose = False               # Otro valor es: True
no_speech_threshold = 0.5     # El rago de valores es: [0,1]
temperature = 0               # El rango de valores es: [0,1]
beam_size = 5                 # El rango de valores es: [1,10]

# %%
#@title 👉  Sólo **transcribir** audio al idioma original. (X ► X)

# !whisper "$audio" --task transcribe --model "$model" --device "$device" --fp16 "$fp16" --verbose "$verbose" --output_dir "$output_dir" --no_speech_threshold "$no_speech_threshold" --temperature "$temperature" --beam_size "$beam_size"
# Out:
# 100%|██████████████████████████████████████| 72.1M/72.1M [00:00<00:00, 143MiB/s]
# Detected language: Spanish
# 100% 138504/138504 [07:07<00:00, 323.65frames/s]
